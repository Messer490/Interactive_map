    '2011': [733281, 777501, 1872844, 532033, 608334, 1046260, 1352217, 881656, 700511, 524185, 746224, 589421, 2567611, 1398078, 697162, 1413152],
    '2012': [731399, 786390, 1908785, 542959, 612581, 1055822, 1357969, 879635, 712899, 545789, 747167, 583772, 2621472, 1395060, 742868, 1449366],
    '2013': [732768, 795871, 1946831, 555199, 617735, 1069785, 1362777, 880116, 726692, 567770, 749201, 579700, 2678739, 1394068, 778145, 1474849],
    '2014': [735612, 808985, 1984572, 567831, 624085, 1084369, 1369658, 880968, 739726, 587431, 752914, 575945, 2733053, 1394388, 814419, 1506899],
    '2015': [736560, 822557, 1921888, 581389, 630056, 1098489, 1378121, 881569, 753001, 606843, 755793, 571830, 2787906, 1395466, 852803, 1641444],
    '2016': [744420, 834808, 1947552, 594511, 636980, 1107499, 1384810, 883806, 765058, 626774, 758594, 569594, 2840871, 1396019, 872584, 1702766],
    '2017': [734369, 845679, 1983465, 607528, 641513, 1115307, 1382734, 879134, 773143, 642824, 757014, 563300, 2840871, 1389568, 972692, 1751308],
    '2018': [738942, 857711, 2017278, 620684, 646927, 1135307, 1380537, 875616, 783157, 660317, 754854, 558584, 2908372, 1383745, 1030577, 1801993],
    '2019': [738587, 869637, 2038935, 633791, 652325, 1137218, 1380537, 872795, 794335, 678199, 753853, 554517, 2945961, 1378527, 1078384, 1854656],
    '2020': [736735, 881651, 2055724, 645280, 656844, 1130099, 1376882, 868549, 803531, 698796, 752169, 548755, 3016037, 1369597, 1136156, 1916822],
    '2021': [735566, 894333, 2077967, 657110, 661316, 1139192, 1375938, 864550, 814588, 719571, 751012, 543735, 3044742, 1375725, 1184411, 1977258],
    '2022': [785708, 916750, 2107796, 681241, 683327, 1154615, 1378126, 835686, 823251, 745909, 756511, 539111, 3108795, 1377417, 1295711, 2101485],
    '2023': [788013, 928159, 2144335, 693079, 688127, 1162279, 1384266, 832234, 833666, 767106, 754944, 534104, 3173487, 1379110, 1354556, 2161902],
    '2024': [787976, 939405, 2158811, 704074, 693261, 1169194, 1390621, 829984, 841929, 786837, 753933, 530089, 3209297, 1382294, 1430117, 2228677],
}

df = pd.DataFrame(data)

# Преобразуем данные для кластеризации: используем популяцию 2020-2024 года для кластеризации
df_cluster = df[['region', '2020', '2021', '2022', '2023', '2024']]

# Нормализуем данные для кластеризации
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_cluster.iloc[:, 1:])  # Нормализуем только данные по популяции

# Применяем K-Means для кластеризации
kmeans = KMeans(n_clusters=3, random_state=42)  # 3 кластера, можно изменить на нужное количество
df_cluster['cluster'] = kmeans.fit_predict(scaled_data)

# 1. Визуализация кластеров на графике популяции в 2020 году
plt.figure(figsize=(10, 6))
for cluster in df_cluster['cluster'].unique():
    cluster_data = df_cluster[df_cluster['cluster'] == cluster]
    plt.scatter(cluster_data.index, cluster_data['2020'], label=f'Cluster {cluster}', s=100)
plt.title('Region Clusters based on Population (2020)')
plt.xlabel('Region')
plt.ylabel('Population in 2020')
plt.legend(loc='best')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# 2. Распределение популяции для каждого кластера (гистограмма)
plt.figure(figsize=(10, 6))
sns.histplot(df_cluster[df_cluster['cluster'] == 0]['2020'], kde=True, color='blue', label='Cluster 0', bins=10)
sns.histplot(df_cluster[df_cluster['cluster'] == 1]['2020'], kde=True, color='green', label='Cluster 1', bins=10)
sns.histplot(df_cluster[df_cluster['cluster'] == 2]['2020'], kde=True, color='red', label='Cluster 2', bins=10)
plt.title('Population Distribution by Cluster (2020)')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# 3. Параллельные координаты для всех признаков
from sklearn.decomposition import PCA

# Применяем PCA для уменьшения размерности
pca = PCA(n_components=2)
pca_components = pca.fit_transform(scaled_data)

# Создаем DataFrame с компонентами PCA и кластерами
df_pca = pd.DataFrame(pca_components, columns=['PCA 1', 'PCA 2'])
df_pca['cluster'] = df_cluster['cluster']

# Визуализируем параллельные координаты
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pca, x='PCA 1', y='PCA 2', hue='cluster', palette='Set1', s=100)
plt.title('PCA Projection of Clusters')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# 4. Тепловая карта корреляции для анализа взаимосвязей между показателями популяции
corr_matrix = df_cluster.iloc[:, 1:5].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Population Data (2020-2024)')
plt.tight_layout()
plt.show()

# Дополнительно можно вывести данные по кластерам
print(df_cluster[['region', 'cluster']])
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12056\81200482.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cluster['cluster'] = kmeans.fit_predict(scaled_data)
#                   region  cluster
# 0                 Akmola        2
# 1                 Aktobe        2
# 2                 Almaty        1
# 3                 Atyrau        2
# 4       Batys Kazakhstan        2
# 5                Zhambyl        0
# 6              Karagandy        0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.decomposition import PCA

# Данные по урбанистическим регионам
data = {
    'region': ['Akmola', 'Aktobe', 'Almaty', 'Atyrau', 'Batys Kazakhstan', 'Zhambyl', 'Karagandy', 'Kostanay', 'Kyzylorda', 'Mangistau', 'Pavlodar', 'Soltustik Kazakhstan', 'Turkistan', 'Shygys Kazakhstan', 'Astana city', 'Almaty city'],
    '2000': [367684, 373225, 462726, 256340, 247271, 448066, 1143378, 532140, 361538, 246891, 501062, 270265, 786214, 889337, 380990, 1130439],
    '2001': [357859, 368122, 458344, 258275, 245504, 442951, 1124388, 513401, 360302, 250870, 490839, 266183, 828605, 878788, 440209, 1128759],
    '2002': [347955, 363356, 456441, 261070, 249526, 439473, 1111008, 500832, 359442, 252358, 485076, 261608, 846689, 869011, 493062, 1132424],
    '2003': [346306, 365276, 459141, 263566, 255884, 439752, 1106348, 495270, 360527, 260674, 480657, 255283, 854800, 862029, 501998, 1149641],
    '2004': [349153, 369209, 464726, 261098, 259550, 442598, 1109026, 495306, 362323, 265761, 483220, 246823, 866685, 857023, 510533, 1175208],
    '2005': [352204, 374775, 473978, 261702, 262518, 447406, 1116456, 498630, 364248, 274628, 487817, 227440, 880663, 853366, 529335, 1209485],
    '2006': [354580, 380427, 479933, 269068, 267283, 451223, 1125124, 480327, 368118, 263012, 488755, 227747, 891826, 850763, 550438, 1247896],
    '2007': [358270, 386710, 488202, 274614, 268432, 453962, 1133622, 483541, 372097, 269128, 493484, 230134, 908824, 850535, 574448, 1287246],
    '2008': [333559, 379195, 382987, 235396, 272886, 427067, 1042220, 431406, 223291, 234734, 490553, 230230, 890056, 764932, 602684, 1324739],
    '2009': [342188, 460251, 424687, 239034, 277055, 415047, 1039005, 439558, 283971, 262237, 504004, 237442, 970164, 801145, 605254, 1361877],
    '2010': [342340, 465370, 431646, 247283, 283677, 420278, 1048067, 441264, 290488, 269442, 508777, 238032, 988720, 804474, 649152, 1390610],
    '2011': [342449, 478191, 438498, 254155, 290025, 422763, 1055760, 443293, 295745, 275840, 511891, 238869, 1007801, 808328, 697162, 1430152],
    '2012': [341776, 484995, 444588, 260660, 297123, 422200, 1063265, 446467, 302088, 281915, 514499, 238501, 1025531, 811701, 742868, 1469863],
    '2013': [344254, 490642, 451970, 268176, 303093, 427848, 1068412, 451006, 309941, 287759, 518334, 239297, 1048342, 815803, 778145, 1513247],
    '2014': [346400, 498846, 457747, 265207, 307093, 436433, 1077487, 454765, 316721, 293110, 524977, 241337, 1069661, 822473, 814419, 1553562],
    '2015': [347353, 510608, 465755, 274324, 312408, 442690, 1088185, 460358, 324986, 268107, 529959, 243231, 1247244, 827570, 852803, 1604203],
    '2016': [351228, 521215, 471018, 283404, 317342, 449510, 1096741, 467277, 333687, 271572, 534532, 248935, 1277777, 835989, 872584, 1653571],
    '2017': [348692, 585938, 474717, 318107, 324459, 448670, 1098499, 468822, 340834, 273540, 534667, 250202, 1377777, 838305, 972692, 1702475],
    '2018': [348685, 602135, 464453, 325421, 333263, 443895, 1099145, 472807, 346193, 269243, 533477, 251737, 1460241, 845758, 1030577, 1752675],
    '2019': [348269, 614492, 457411, 330218, 339259, 447006, 1097418, 475681, 352020, 271054, 532029, 252673, 1545565, 849152, 1078384, 1802691],
    '2020': [348117, 628017, 451551, 352241, 344398, 448133, 1097991, 503449, 358114, 276648, 530762, 252826, 1634174, 849730, 1136156, 1851223],
    '2021': [349320, 640960, 455085, 357787, 348278, 454055, 1099620, 504909, 364939, 287713, 530225, 253204, 1693921, 851472, 1184411, 1903684],
    '2022': [438207, 681135, 241061, 376056, 382273, 521943, 920015, 513228, 385564, 336108, 533199, 259143, 1744341, 851472, 1235711, 1957852],
    '2023': [441997, 692467, 243889, 382459, 386775, 526938, 922380, 515257, 391207, 346958, 532886, 258935, 1792703, 483403, 1295711, 2013269],
    '2024': [445712, 703670, 247519, 389872, 391734, 530816, 926202, 517698, 395163, 358231, 533211, 259340, 1842939, 483947, 1354556, 2060717],
}

# Чтение данных в pandas DataFrame
df_urban = pd.DataFrame(data)

# Преобразуем данные: исключаем столбец с названиями регионов и превращаем данные в числовые
X = df_urban.drop('region', axis=1).values

# Стандартизируем данные (важно для кластеризации)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Применяем KMeans для кластеризации (предположим 3 кластера)
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)
df_urban['Cluster'] = kmeans.labels_

# Визуализируем результаты
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_urban, x='2000', y='2024', hue='Cluster', palette='viridis', s=100, marker='o')
plt.title("Cluster Analysis of Urban Regions (2000 vs 2024)")
plt.xlabel('Population in 2000')
plt.ylabel('Population in 2024')
plt.legend(title='Cluster')
plt.show()

# Применим PCA для двухмерной визуализации
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=df_urban['Cluster'], palette='viridis', s=100)
plt.title("PCA Visualization of Clusters")
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.show()

# График изменения населения с 2000 по 2024 год для каждого региона
# График изменения населения с 2000 по 2024 год для каждого региона
plt.figure(figsize=(12, 8))
for i, region in enumerate(df_urban['region']):
    # Use the full range of years (2000 to 2024) for both x and y
    plt.plot(df_urban.columns[1:], df_urban.iloc[i, 1:], label=region)
plt.title("Изменение населения с 2000 по 2024 год по регионам")
plt.xlabel("Год")
plt.ylabel("Население")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Данные о населении по регионам
data = {
    'region': ['Akmola', 'Aktobe', 'Almaty', 'Atyrau', 'Batys Kazakhstan', 'Zhambyl', 
               'Karagandy', 'Kostanay', 'Kyzylorda', 'Mangistau', 'Pavlodar', 'Soltustik Kazakhstan', 
               'Turkistan', 'Shygys Kazakhstan', 'Astana city', 'Almaty city'],
    '2000':
    '2021': [386246, 253373, 1622882, 299323, 313038, 685137, 276318, 359641, 449649, 431858, 220787, 
             290531, 1643063, 512325, 512325, 1977258],
    '2022': [347501, 235615, 1237435, 305185, 301054, 687722, 214951, 322458, 437687, 409801, 223312, 
             279968, 1579918, 250050, 250050, 2101485],
    '2023': [346016, 235692, 1262007, 310620, 301352, 691220, 212475, 316977, 442459, 420148, 222058, 
             275169, 1599983, 246835, 246835, 2161902],
    '2024': [342264, 235735, 1283648, 314202, 301527, 691777, 209149, 312286, 446766, 428606, 220722, 
             270749, 1614071, 243106, 243106, 2228677]
}

# Преобразуем данные в DataFrame
df = pd.DataFrame(data)

# Make sure all years are numeric
df.iloc[:, 1:] = df.iloc[:, 1:].apply(pd.to_numeric)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Extract the population data (excluding the region column)
population_data = df.iloc[:, 1:].values

# Perform KMeans clustering
kmeans = KMeans(n_clusters=3)  # Example with 3 clusters
df['Cluster'] = kmeans.fit_predict(population_data)

# Display the regions and their corresponding clusters
print(df[['region', 'Cluster']])
# Out:
#                   region  Cluster
# 0                 Akmola        1
# 1                 Aktobe        1
# 2                 Almaty        0
# 3                 Atyrau        1
# 4       Batys Kazakhstan        1
# 5                Zhambyl        1
# 6              Karagandy        1
# 7               Kostanay        1
# 8              Kyzylorda        1
# 9              Mangistau        1
# 10              Pavlodar        1
# 11  Soltustik Kazakhstan        1
# 12             Turkistan        0
# 13     Shygys Kazakhstan        1
# 14           Astana city        1
# 15           Almaty city        2
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.decomposition import PCA

# Reduce dimensions for visualization
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(population_data)

# Plot the reduced data, color-coded by clusters
plt.figure(figsize=(8, 6))
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=df['Cluster'], cmap='viridis')
plt.title("ПCA для кластеризации населения по регионам")
plt.xlabel("PCA компонент 1")
plt.ylabel("PCA компонент 2")
plt.colorbar(label='Cluster')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Данные о населении по регионам
data = {
    'region': ['Akmola', 'Aktobe', 'Almaty', 'Atyrau', 'Batys Kazakhstan', 'Zhambyl', 
               'Karagandy', 'Kostanay', 'Kyzylorda', 'Mangistau', 'Pavlodar', 'Soltustik Kazakhstan', 
               'Turkistan', 'Shygys Kazakhstan', 'Astana city', 'Almaty city'],
    '2000': [431495, 304490, 1094415, 185352, 361890, 538078, 247076, 456647, 236988, 68312, 289712, 
             443363, 1218809, 627448, 627448, 1130439],
    '2001': [418518, 302109, 1095976, 185355, 356144, 538977, 240393, 445873, 239436, 68321, 281614, 
             436440, 1222746, 620309, 620309, 1128759],
    '2002': [407045, 304810, 1098132, 186564, 350804, 539726, 233236, 434885, 241530, 75907, 273078, 
             429655, 1232817, 613539, 613539, 1132424],
    '2003': [401861, 303102, 1101126, 188362, 346249, 540320, 227308, 424288, 243277, 77938, 267994, 
             426865, 1257093, 603902, 603902, 1149641],
    '2004': [399777, 302603, 1110468, 196117, 344282, 542954, 221901, 418129, 245168, 83907, 262018, 
             427674, 1283571, 598389, 598389, 1175208],
    '2005': [394981, 303832, 1115773, 201764, 344016, 544683, 215246, 408766, 247800, 87126, 256009, 
             438496, 1312893, 588731, 588731, 1209485],
    '2006': [392072, 306271, 1123825, 203316, 342008, 549871, 209314, 422851, 250131, 111418, 254156, 
             435379, 1341742, 580417, 580417, 1247896],
    '2007': [390289, 308744, 1132494, 206073, 344047, 555248, 205746, 416792, 252973, 121403, 251376, 
             430816, 1373650, 573978, 573978, 1287246],
    '2008': [413888, 324465, 1132494, 254973, 342424, 591778, 299861, 462786, 408943, 172669, 255901, 
             423691, 1441449, 652452, 652452, 1324739],
    '2009': [396639, 296531, 1379318, 270089, 321287, 605749, 302202, 446771, 393763, 220394, 238272, 
             360092, 1492618, 595726, 595726, 1361877],
    '2010': [392794, 298221, 1404516, 273705, 320181, 614209, 298755, 442115, 398523, 233799, 235618, 
             354759, 1522860, 593599, 593599, 1390610],
    '2011': [390832, 299310, 1434346, 277878, 318309, 623497, 296457, 438363, 404766, 248345, 234333, 
             350552, 1559810, 589750, 589750, 1413152],
    '2012': [389623, 301395, 1464197, 282299, 315458, 633622, 294704, 433168, 410811, 263874, 232668, 
             345271, 1595941, 583359, 583359, 1449366],
    '2013': [388514, 305229, 1494861, 287023, 314642, 641937, 294365, 429110, 416751, 280011, 230867, 
             340403, 1630397, 578265, 578265, 1474849],
    '2014': [389212, 310139, 1526825, 302624, 316992, 647936, 292171, 426203, 423005, 294321, 227937, 
             334608, 1663392, 571915, 571915, 1506899],
    '2015': [389207, 311949, 1456133, 307065, 317648, 655799, 289936, 421211, 428015, 338736, 225834, 
             328599, 1540662, 567896, 567896, 1641444],
    '2016': [393192, 313593, 1476534, 311107, 319638, 661239, 288069, 416529, 431371, 355202, 224062, 
             320659, 1563094, 560030, 560030, 1702766],
    '2017': [385677, 259741, 1508538, 289421, 317054, 666637, 284235, 410312, 432309, 369284, 222347, 
             313098, 1576596, 551263, 551263, 1751308],
    '2018': [390257, 255576, 1552825, 295263, 313664, 673323, 281392, 402809, 436964, 391074, 221377, 
             306847, 1615517, 537987, 537987, 1801993],
    '2019': [390318, 255145, 1581524, 303573, 313066, 678434, 281114, 397114, 442315, 407145, 221824, 
             301844, 1638968, 529375, 529375, 1854656],
    '2020': [388618, 253634, 1604173, 293039, 312446, 681966, 278891, 365100, 445417, 422148, 221407, 
             295929, 1610492, 519867, 519867, 1916822],
    '2021': [386246, 253373, 1622882, 299323, 313038, 685137, 276318, 359641, 449649, 431858, 220787, 
             290531, 1643063, 512325, 512325, 1977258],
    '2022': [347501, 235615, 1237435, 305185, 301054, 687722, 214951, 322458, 437687, 409801, 223312, 
             279968, 1579918, 250050, 250050, 2101485],
    '2023': [346016, 235692, 1262007, 310620, 301352, 691220, 212475, 316977, 442459, 420148, 222058, 
             275169, 1599983, 246835, 246835, 2161902],
    '2024': [342264, 235735, 1283648, 314202, 301527, 691777, 209149, 312286, 446766, 428606, 220524, 
             270694, 1620356, 242160, 242160, 2222069]
}

df = pd.DataFrame(data)

# Кластеризация
kmeans = KMeans(n_clusters=4)
df['Cluster'] = kmeans.fit_predict(df.iloc[:, 1:])

# Для правильного отображения данных на графике
years = df.columns[1:-1]

# Построение графика
plt.figure(figsize=(10, 6))
for i, row in df.iterrows():
    plt.plot(years, row[1:-1], label=row['region'], color=plt.cm.tab10(row['Cluster'] / 3))

plt.title("Изменение населения по регионам (с 2000 по 2024)")
plt.xlabel("Год")
plt.ylabel("Население")
plt.legend(loc="best")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd
import matplotlib.pyplot as plt

# Данные о популяции (пример)
df_population = pd.DataFrame({
    'year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'population': [14901641, 14865610, 14851059, 14866837, 14951200, 15074767, 15219291, 15396878, 15571506, 15982370, 16203274, 16440470, 16673933, 16910246, 17160855, 17415715, 17669896, 17918214, 18157337, 18395567, 18631779, 18879552, 19503159, 19766807]
})

# Применяем Isolation Forest для обнаружения аномалий
model = IsolationForest(contamination=0.1)  # Устанавливаем порог для аномалий
df_population['anomaly'] = model.fit_predict(df_population[['population']])

# Аномалии будут иметь значение -1
anomalies = df_population[df_population['anomaly'] == -1]

# Выводим аномальные года
print("Аномальные года по популяции:")
print(anomalies[['year', 'population']])

# Визуализация временного ряда
plt.figure(figsize=(10, 6))
plt.plot(df_population['year'], df_population['population'], label='Population', color='blue')
plt.scatter(anomalies['year'], anomalies['population'], color='red', label='Anomalies', zorder=5)
plt.title('Population with Anomalies')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Аномальные года по популяции:
#     year  population
# 21  2021    18879552
# 22  2022    19503159
# 23  2023    19766807

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

# Данные о населении по регионам и годам
data = {
    'region': ['Akmola', 'Aktobe', 'Almaty', 'Atyrau', 'Batys Kazakhstan', 'Zhambyl', 'Karagandy', 'Kostanay', 'Kyzylorda', 'Mangistau', 'Pavlodar', 'Soltustik Kazakhstan', 'Turkistan', 'Shygys Kazakhstan', 'Astana city', 'Almaty city'],
    '2000': [367684, 373225, 462726, 256340, 247271, 448066, 1143378, 532140, 361538, 246891, 501062, 270265, 786214, 889337, 380990, 1130439],
    '2001': [357859, 368122, 458344, 258275, 245504, 442951, 1124388, 513401, 360302, 250870, 490839, 266183, 828605, 878788, 440209, 1128759],
    '2002': [347955, 363356, 456441, 261070, 249526, 439473, 1111008, 500832, 359442, 252358, 485076, 261608, 846689, 869011, 493062, 1132424],
    '2003': [346306, 365276, 459141, 263566, 255884, 439752, 1106348, 495270, 360527, 260674, 480657, 255283, 854800, 862029, 501998, 1149641],
    '2004': [349153, 369209, 464726, 261098, 259550, 442598, 1109026, 495306, 362323, 265761, 483220, 246823, 866685, 857023, 510533, 1175208],
    '2005': [352204, 374775, 473978, 261702, 262518, 447406, 1116456, 498630, 364248, 274628, 487817, 227440, 880663, 853366, 529335, 1209485],
    '2006': [354580, 380427, 479933, 269068, 267283, 451223, 1125124, 480327, 368118, 263012, 488755, 227747, 891826, 850763, 550438, 1247896],
    '2007': [358270, 386710, 488202, 274614, 268432, 453962, 1133622, 483541, 372097, 269128, 493484, 230134, 908824, 850535, 574448, 1287246],
    '2008': [333559, 379195, 382987, 235396, 272886, 427067, 1042220, 431406, 223291, 234734, 490553, 230230, 890056, 764932, 602684, 1324739],
    '2009': [342188, 460251, 424687, 239034, 277055, 415047, 1039005, 439558, 283971, 262237, 504004, 237442, 970164, 801145, 605254, 1361877],
    '2010': [342340, 465370, 431646, 247283, 283677, 420278, 1048067, 441264, 290488, 269442, 508777, 238032, 988720, 804474, 649152, 1390610],
    '2011': [342449, 478191, 438498, 254155, 290025, 422763, 1055760, 443293, 295745, 275840, 511891, 238869, 1007801, 808328, 697162, 1430152],
    '2012': [341776, 484995, 444588, 260660, 297123, 422200, 1063265, 446467, 302088, 281915, 514499, 238501, 1025531, 811701, 742868, 1469863],
    '2013': [344254, 490642, 451970, 268176, 303093, 427848, 1068412, 451006, 309941, 287759, 518334, 239297, 1048342, 815803, 778145, 1513247],
    '2014': [346400, 498846, 457747, 265207, 307093, 436433, 1077487, 454765, 316721, 293110, 524977, 241337, 1069661, 822473, 814419, 1553562],
    '2015': [347353, 510608, 465755, 274324, 312408, 442690, 1088185, 460358, 324986, 268107, 529959, 243231, 1247244, 827570, 852803, 1604203],
    '2016': [351228, 521215, 471018, 283404, 317342, 449510, 1096741, 467277, 333687, 271572, 534532, 248935, 1277777, 835989, 872584, 1653571],
    '2017': [348692, 585938, 474717, 318107, 324459, 448670, 1098499, 468822, 340834, 273540, 534667, 250202, 1377777, 838305, 972692, 1702475],
    '2018': [348685, 602135, 464453, 325421, 333263, 443895, 1099145, 472807, 346193, 269243, 533477, 251737, 1460241, 845758, 1030577, 1752675],
    '2019': [348269, 614492, 457411, 330218, 339259, 447006, 1097418, 475681, 352020, 271054, 532029, 252673, 1545565, 849152, 1078384, 1802691],
    '2020': [348117, 628017, 451551, 352241, 344398, 448133, 1097991, 503449, 358114, 276648, 530762, 252826, 1634174, 849730, 1136156, 1851223],
    '2021': [349320, 640960, 455085, 357787, 348278, 454055, 1099620, 504909, 364939, 287713, 530225, 253204, 1693921, 851472, 1184411, 1903684],
    '2022': [438207, 681135, 241061, 376056, 382273, 521943, 920015, 513228, 385564, 336108, 533199, 259143, 1744341, 851472, 1235711, 1957852],
    '2023': [441997, 692467, 243889, 382459, 386775, 526938, 922380, 515257, 391207, 346958, 532886, 258935, 1792703, 483403, 1295711, 2013269],
    '2024': [445712, 703670, 247519, 389872, 391734, 530816, 926202, 517698, 395163, 358231, 533211, 259340, 1842939, 483947, 1354556, 2060717],
}

# Создание DataFrame
df = pd.DataFrame(data)

# Преобразуем данные в форму, подходящую для анализа: регионы - строки, годы - столбцы
df_melted = pd.melt(df, id_vars=['region'], var_name='year', value_name='population')

# Преобразуем год в числовой формат для корректной работы модели
df_melted['year'] = pd.to_numeric(df_melted['year'])

# Применяем модель для поиска аномалий
model = IsolationForest(contamination=0.1)  # Используем 10% для обнаружения аномалий
df_melted['anomaly'] = model.fit_predict(df_melted[['population']])

# Аномалии будут помечены как -1
anomalies = df_melted[df_melted['anomaly'] == -1]

# Выводим аномальные данные
print("Аномальные изменения населения:")
print(anomalies)

# Визуализация
plt.figure(figsize=(12, 6))

# Плотаем все данные
for region in df['region']:
    region_data = df_melted[df_melted['region'] == region]
    plt.plot(region_data['year'], region_data['population'], label=region)

# Выделяем аномалии красным
plt.scatter(anomalies['year'], anomalies['population'], color='red', label='Anomalies', zorder=5)

plt.title('Population Changes and Anomalies by Region')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Аномальные изменения населения:
#                    region  year  population  anomaly
# 91   Soltustik Kazakhstan  2005      227440       -1
# 95            Almaty city  2005     1209485       -1
# 111           Almaty city  2006     1247896       -1
# 127           Almaty city  2007     1287246       -1
# 136             Kyzylorda  2008      223291       -1
# 143           Almaty city  2008     1324739       -1
# 159           Almaty city  2009     1361877       -1
# 175           Almaty city  2010     1390610       -1
# 190           Astana city  2011      697162       -1
# 191           Almaty city  2011     1430152       -1
# 206           Astana city  2012      742868       -1
# 207           Almaty city  2012     1469863       -1
# 223           Almaty city  2013     1513247       -1
# 239           Almaty city  2014     1553562       -1
# 252             Turkistan  2015     1247244       -1
# 255           Almaty city  2015     1604203       -1
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Данные о рождаемости (в примерном формате)
data = {
    'region': ['Akmola', 'Aktobe', 'Almaty', 'Atyrau', 'Batys Kazakhstan', 'Zhambyl', 'Karagandy', 'Kostanay', 'Kyzylorda', 'Mangistau', 'Pavlodar', 'Soltustik Kazakhstan', 'Turkistan', 'Shygys Kazakhstan', 'Astana city', 'Almaty city'],
    '2000':
    '2023': [10901, 19206, 33607, 16548, 12010, 25872, 16343, 9670, 20010, 20780, 9838, 5554, 55775, 8718, 29415, 35488],
    '2024': [939405, 1531167, 704074, 693261, 1222593, 1135351, 841929, 786837, 753933, 530089, 2142172, 727053, 1430117, 8718, 29415, 35488]
}

# Преобразуем данные в DataFrame
df = pd.DataFrame(data)

# Установим индекс как регион
df.set_index('region', inplace=True)

# Построим график для нескольких регионов
regions_to_plot = ['Akmola', 'Aktobe', 'Almaty', 'Atyrau', 'Zhambyl']  # Пример регионов для графика

plt.figure(figsize=(10, 6))

for region in regions_to_plot:
    plt.plot(df.columns, df.loc[region], marker='o', label=region)

plt.title('Динамика рождаемости по регионам')
plt.xlabel('Год')
plt.ylabel('Рождаемость')
plt.legend(title="Регионы")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Данные для графика
data = {
    'region': ['Akmola', 'Aktobe', 'Almaty', 'Atyrau', 'Batys Kazakhstan', 'Zhambyl', 'Karagandy', 'Kostanay', 'Kyzylorda', 'Mangistau', 'Pavlodar', 'Soltustik Kazakhstan', 'Turkistan', 'Shygys Kazakhstan', 'Astana city', 'Almaty city'],
    '2000': [10075, 9908, 23770, 8235, 7779, 16981, 16067, 10759, 12720, 6179, 8857, 8018, 46316, 17025, 4465, 14900],
    '2001': [10243, 9662, 23274, 8340, 7822, 17196, 16421, 10738, 12251, 6697, 8664, 7935, 47406, 16306, 4750, 13782],
    '2002': [9918, 9902, 23846, 8662, 8112, 16040, 16914, 10945, 12126, 7459, 9069, 8011, 47476, 17013, 5585, 16093],
    '2003': [10375, 10781, 26041, 9554, 9010, 18376, 18380, 11485, 12491, 8086, 9695, 8277, 51051, 18288, 6449, 19607],
    '2004': [10976, 12092, 27906, 9834, 9820, 20681, 19373, 11505, 13923, 9385, 10469, 8223, 57807, 19397, 7990, 23647],
    '2005': [10633, 13036, 27679, 10806, 9613, 21522, 19842, 10977, 13897, 9898, 10395, 8529, 57733, 19638, 9042, 25737],
    '2006': [11442, 13644, 30567, 11718, 10046, 23850, 20976, 11345, 15208, 11248, 11026, 8308, 63028, 21205, 10026, 28119],
    '2007': [11589, 14404, 34220, 12095, 10514, 25505, 21707, 11319, 16491, 12201, 11477, 8277, 68287, 21741, 12511, 29625],
    '2008': [12532, 15885, 38807, 13585, 11601, 28075, 22623, 12422, 18604, 13348, 12783, 9085, 75449, 23661, 15054, 34041],
    '2009': [13204, 16566, 43260, 14207, 11782, 28136, 23240, 12572, 19090, 14266, 12597, 8880, 73882, 23993, 15153, 25433],
    '2010': [12539, 17176, 45527, 14867, 11942, 28586, 23459, 12843, 20026, 14785, 12310, 8721, 78474, 23572, 17345, 25535],
    '2011': [12675, 17788, 45940, 15316, 11896, 28783, 24291, 12744, 20119, 16076, 12912, 8667, 79492, 22931, 17865, 25195],
    '2012': [13437, 18223, 46875, 15586, 12425, 28436, 24508, 13109, 20220, 16960, 12868, 8721, 80099, 23385, 19463, 26838],
    '2013': [12857, 18757, 48475, 16065, 12723, 28883, 24680, 13029, 19674, 18322, 13105, 8561, 80093, 22825, 21896, 27311],
    '2014': [12803, 19625, 50023, 16389, 13040, 29581, 24913, 12763, 20358, 19198, 13041, 8216, 81979, 23726, 24082, 29672],
    '2015': [12674, 19980, 48954, 16424, 12974, 28408, 24496, 12769, 19677, 19305, 12771, 8132, 81709, 22892, 26134, 31159],
    '2016': [12496, 19769, 50874, 16730, 13184, 28121, 23950, 12290, 19256, 19794, 12613, 7694, 81456, 22918, 27876, 31704],
    '2017': [12307, 19138, 49971, 16443, 12860, 26465, 22715, 11736, 18982, 19380, 12025, 7387, 53252, 22164, 29276, 31423],
    '2018': [12426, 19599, 50409, 17033, 13067, 27113, 22950, 11630, 19195, 19892, 11856, 7194, 54134, 21861, 29181, 33259],
    '2019': [12265, 20493, 50502, 16980, 13130, 27041, 23034, 11448, 19347, 20459, 11558, 6872, 55738, 21854, 28736, 34308],
    '2020': [12506, 21287, 54355, 18002, 13670, 29171, 23423, 11671, 21780, 21734, 11771, 6879, 61258, 22514, 29565, 35526],
    '2021': [12856, 22153, 55186, 18428, 14241, 30475, 23987, 11174, 23682, 23349, 11667, 6489, 65059, 23061, 31395, 37922],
    '2022': [11561, 19302, 34979, 17161, 12536, 26723, 16812, 10355, 20769, 21581, 10655, 5879, 58214, 9483, 30302, 36110],
    '2023': [10901, 19206, 33607, 16548, 12010, 25872, 16343, 9670, 20010, 20780, 9838, 5554, 55775, 8718, 29415, 35488],
    '2024': [939405, 1531167, 704074, 693261, 1222593, 1135351, 841929, 786837, 753933, 530089, 2142172, 727053, 1430117, 8718, 29415, 35488]
}
# Создаем линейный график
plt.figure(figsize=(12, 8))
for i, region in enumerate(data['region']):
    # Собираем значения для каждого региона по годам
    region_data = [data[year][i] for year in data if year != 'region']
    plt.plot(list(data.keys())[1:], region_data, label=region)

# Настройки графика
plt.title("Рождаемость по регионам (2000-2024)")
plt.xlabel("Год")
plt.ylabel("Число рождений")
plt.xticks(rotation=45)
plt.legend(title="Регион", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)

# Показать график
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Подготовим данные для тепловой карты
df = pd.DataFrame(data)
df.set_index('region', inplace=True)

# Строим тепловую карту
plt.figure(figsize=(16, 12))
sns.heatmap(df, annot=True, cmap="YlGnBu", fmt="d", linewidths=0.5)

# Настройки графика
plt.title("Тепловая карта рождаемости по регионам и годам")
plt.xlabel("Год")
plt.ylabel("Регион")

# Показать график
plt.tight_layout()
plt.show()

# %%
# Рождаемость в 2020 году
years_2020 = [data['2020'][i] for i in range(len(data['region']))]

# Строим гистограмму
plt.figure(figsize=(10, 6))
plt.bar(data['region'], years_2020, color='skyblue')

# Настройки графика
plt.title("Сравнение рождаемости по регионам в 2020 году")
plt.xlabel("Регион")
plt.ylabel("Число рождений")
plt.xticks(rotation=90)
plt.grid(True, axis='y')

# Показать график
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Примерные значения для предсказаний
y_true = [1, 0, 1, 1, 0, 0, 1, 0, 1, 0]  # Истинные значения
y_pred = [1, 0, 1, 0, 0, 0, 1, 1, 1, 0]  # Предсказанные значения

# Вычисление метрик
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

# Печать результатов
print(f"Точность (Accuracy): {accuracy:.2f}")
print(f"Точность (Precision): {precision:.2f}")
print(f"Полнота (Recall): {recall:.2f}")
print(f"F1-мерка (F1-score): {f1:.2f}")
# Out:
# Точность (Accuracy): 0.80
# Точность (Precision): 0.80
# Полнота (Recall): 0.80
# F1-мерка (F1-score): 0.80
